# %%
from cminpack_numba import lmdif1, lmdif, lmdif_sig
import numpy as np
import numba as nb
from scipy.optimize import leastsq
import jax
import jax.numpy as jnp
from cminpack_numba.scipy_overloads import *


@nb.cfunc(lmdif_sig)
def func_numba(udata, m, n, x, fvec, iflag):
    fvec[0] = 2.0 * (x[0] - 3.0) ** 2 + 1.0*x[1]
    fvec[1] = 3.0 * (x[0] - 4.0) ** 2 + 2.0*x[1]
    fvec[2] = 4.0 * (x[0] - 5.0) ** 2 + 3.0*x[1]
    fvec[3] = 5.0 * (x[0] - 6.0) ** 2 + 4.0*x[1]
    fvec[4] = 6.0 * (x[0] - 7.0) ** 2 + 5.0*x[1]
    return 0

def func_scipy(x, args=()):
    return np.array([2.0 * (x[0] - 3.0) ** 2 + 1.0*x[1], 3.0 * (x[0] - 4.0) ** 2 + 2.0*x[1], 4.0 * (x[0] - 5.0) ** 2 + 3.0*x[1], 5.0 * (x[0] - 6.0) ** 2 + 4.0*x[1], 6.0 * (x[0] - 7.0) ** 2 + 5.0*x[1]])

# %%
leastsq(func_scipy, [0.0, 0.0], full_output=True)
# Out:
# (array([ 5.34948832, -2.06584694]),
#  array([[0.00224468, 0.00371682],
#         [0.00371682, 0.02433627]]),
#  {'fvec': array([ 8.9743438 ,  1.33166231, -5.70897246, -6.14756052,  6.01589815]),
#   'nfev': 26,
#   'fjac': array([[-24.41919434,   0.33158155,   0.1144976 ,  -0.26639192,
#            -0.81108702],
#          [  3.72948693,  -6.41022054,   0.50320715,   0.54209607,
#             0.53061976]]),
#   'ipvt': array([1, 2], dtype=int32),
#   'qtf': array([-7.33239827e-05, -4.30875351e-05])},
#  'Both actual and predicted relative reductions in the sum of squares\n  are at most 0.000000',
#  1)

# %%
lmdif1(func_numba.address, 5, np.array([0.0, 0.0]))
# Out:
# (array([ 5.34948832, -2.06584691]),
#  array([ 8.97434385,  1.33166238, -5.70897239, -6.14756044,  6.01589821]),
#  1)

# %%
lmdif(func_numba.address, 5, np.array([0.0, 0.0]))
# Out:
# (array([0., 0.]),
#  array([ 8.97434385,  1.33166238, -5.70897239, -6.14756044,  6.01589821]),
#  1,
#  array([[-24.41919426,   0.33158155],
#         [  0.1144976 ,  -0.26639192],
#         [ -0.81108701,   3.72948691],
#         [ -6.41022053,   0.50320716],
#         [  0.54209607,   0.53061975]]),
#  array([1, 2], dtype=int32),
#  array([-7.33541237e-05, -4.29710722e-05]),
#  26)

# %%
# %timeit leastsq(func_scipy, [0.0, 0.0], full_output=True)
# %timeit -n 1000 lmdif1(func_numba.address, 5, np.array([0.0, 0.0]))
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]))
ftol = 1.49012e-08
xtol = 1.49012e-08
gtol = 0.0
maxfev = 1000
epsfcn = np.finfo(np.float64).eps
factor = 100.0
diag = np.array([1.0, 1.0])
mode = 1
nprint = 0
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol, xtol, gtol, maxfev, epsfcn, diag, mode, factor, nprint)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), diag=diag)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), epsfcn=epsfcn)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), maxfev=maxfev)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), diag=diag, epsfcn=epsfcn, maxfev=maxfev)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol)#, xtol, gtol, maxfev, epsfcn, diag, mode, factor, nprint)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol, xtol)#, gtol, maxfev, epsfcn, diag, mode, factor, nprint)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol, xtol, gtol, maxfev)#, epsfcn, diag, mode, factor, nprint)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol, xtol, gtol, maxfev, epsfcn)#, diag, mode, factor, nprint)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol, xtol, gtol, maxfev, epsfcn, diag)#, mode, factor, nprint)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol, xtol, gtol, maxfev, epsfcn, diag, mode)#, factor, nprint)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol, xtol, gtol, maxfev, epsfcn, diag, mode, factor)#, nprint)
# %timeit -n 1000 lmdif(func_numba.address, 5, np.array([0.0, 0.0]), ftol, xtol, gtol, maxfev, epsfcn, diag, mode, factor, nprint)
# Out:
# 4.3 µs ± 59.6 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 34.4 µs ± 1.07 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 5.37 µs ± 113 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 37 µs ± 304 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 34.1 µs ± 394 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 35.4 µs ± 403 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 37.1 µs ± 748 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 33.1 µs ± 185 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 32.6 µs ± 392 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 31.8 µs ± 267 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 31.5 µs ± 245 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 34 µs ± 100 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 33.9 µs ± 261 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 33.3 µs ± 441 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 5.31 µs ± 168 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import time
import numba as nb
import numpy as np


@nb.njit
def function(a, b, c, d=1.49012e-8, e=1.49012000000001e-8, f=0.0, g=None):
    ...
        
@nb.njit
def function2(a, b, c, d=1.49012e-8, e=1.49012000000001e-8, f=0.0):
    ...
        
@nb.njit
def function3(a, b, c, d=1.49012e-8, e=1.49012000000001e-8, f=None, g=0.0):
    ...
    
@nb.njit
def function4(a, b, c, d=1.49012e-8, e=1.49012e-8, f=0.0, g=None):
    ...

d = 1.49012e-8
e = 1.49012000000001e-8
f = 0.0
g = 1000

args = (d, e, f, g)
kwargs = {'d': d, 'e': e, 'f': f, 'g': g}
for func in (function, function2, function3, function4):
    func(1, 2, 3)
    
def time_func(func, args, kwargs):
    func(1, 2, 3)
    
    print(func.__name__)
    print("time *args")
    for i, _ in enumerate(args):
        # func(1, 2, 3, *args[:i])
        # %timeit -n 1000 func(1, 2, 3, *args[:i])
    print("time **kwargs")
    for i in kwargs:
        _kwargs = {k: v for k, v in kwargs.items() if k != i}
        # func(1, 2, 3, **_kwargs)
        # %timeit -n 1000 func(1, 2, 3, **_kwargs)

time_func(function, args, kwargs)
time_func(function2, args[:-1], {k: v for k, v in kwargs.items() if k != 'g'})
time_func(function3, args, kwargs)
time_func(function4, args, kwargs)
# Out:
# function
# time *args
# 16.8 µs ± 124 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 18.1 µs ± 4.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 17.1 µs ± 4.37 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# The slowest run took 60.52 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1.89 µs ± 4.14 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# time **kwargs
# The slowest run took 60.45 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1.78 µs ± 3.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 17.1 µs ± 3.77 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 17.4 µs ± 4.63 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 210 ns ± 12.4 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# function2
# time *args
# 16.5 µs ± 247 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 17.6 µs ± 4.36 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 16.8 µs ± 4.54 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# time **kwargs
# The slowest run took 78.96 times longer than the fastest. This could mean that an intermediate result is being cached.
# 2.05 µs ± 4.58 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 16.5 µs ± 4.83 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 14.1 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# function3
# time *args
# 17 µs ± 146 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 17.9 µs ± 4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 17.3 µs ± 4.14 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 16.5 µs ± 4.24 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# time **kwargs
# The slowest run took 64.73 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1.89 µs ± 4.17 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 16.8 µs ± 4.19 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# The slowest run took 62.08 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1.87 µs ± 4.11 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 14.8 µs ± 207 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# function4
# time *args
# 16.6 µs ± 232 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 17.8 µs ± 3.97 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 17.1 µs ± 4.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# The slowest run took 59.96 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1.93 µs ± 4.24 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# time **kwargs
# The slowest run took 65.85 times longer than the fastest. This could mean that an intermediate result is being cached.
# 2 µs ± 4.41 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# The slowest run took 69.15 times longer than the fastest. This could mean that an intermediate result is being cached.
# 2.17 µs ± 4.82 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 18.7 µs ± 5.07 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 206 ns ± 2.58 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
for i in (llvm:=function.inspect_llvm()):
    print(i)
    print(llvm[i])
# Out:
# (int64, int64, int64, omitted(default=1.49012e-08), omitted(default=1.49012000000001e-08), omitted(default=0.0), omitted(default=None))
# ; ModuleID = 'function'
# source_filename = "<string>"
# target datalayout = "e-m:o-i64:64-i128:128-n32:64-S128"
# target triple = "arm64-apple-darwin23.1.0"
#
# @.const.function = internal constant [9 x i8] c"function\00"
# @_ZN08NumbaEnv8__main__8functionB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29EN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29 = common local_unnamed_addr global i8* null
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29EN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29" = internal constant [255 x i8] c"missing Environment: _ZN08NumbaEnv8__main__8functionB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29EN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29\00"
# @_Py_NoneStruct = external global i8
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind willreturn writeonly
# define i32 @_ZN8__main__8functionB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29EN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture readnone %excinfo, i64 %arg.a, i64 %arg.b, i64 %arg.c) local_unnamed_addr #0 {
# entry:
#   store i8* null, i8** %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__8functionB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29EN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = alloca i8*, align 8
#   %.8 = alloca i8*, align 8
#   %.9 = alloca i8*, align 8
#   %.10 = alloca i8*, align 8
#   %.11 = alloca i8*, align 8
#   %.12 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([9 x i8], [9 x i8]* @.const.function, i64 0, i64 0), i64 7, i64 7, i8** nonnull %.5, i8** nonnull %.6, i8** nonnull %.7, i8** nonnull %.8, i8** nonnull %.9, i8** nonnull %.10, i8** nonnull %.11)
#   %.13 = icmp eq i32 %.12, 0
#   %.74 = alloca i8*, align 8
#   store i8* null, i8** %.74, align 8
#   br i1 %.13, label %common.ret, label %entry.endif, !prof !0
#
# common.ret:                                       ; preds = %entry.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry, %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.if
#   %common.ret.op = phi i8* [ null, %entry.endif.if ], [ @_Py_NoneStruct, %entry.endif.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry ], [ null, %entry.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif ]
#   ret i8* %common.ret.op
#
# entry.endif:                                      ; preds = %entry
#   %.17 = load i8*, i8** @_ZN08NumbaEnv8__main__8functionB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29EN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29, align 8
#   %.22 = icmp eq i8* %.17, null
#   br i1 %.22, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([255 x i8], [255 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29EN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29", i64 0, i64 0))
#   br label %common.ret
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.26 = load i8*, i8** %.5, align 8
#   %.29 = call i8* @PyNumber_Long(i8* %.26)
#   %.30.not = icmp eq i8* %.29, null
#   br i1 %.30.not, label %entry.endif.endif.endif, label %entry.endif.endif.if, !prof !0
#
# entry.endif.endif.if:                             ; preds = %entry.endif.endif
#   %.32 = call i64 @PyLong_AsLongLong(i8* nonnull %.29)
#   call void @Py_DecRef(i8* nonnull %.29)
#   br label %entry.endif.endif.endif
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif.if, %entry.endif.endif
#   %.37 = call i8* @PyErr_Occurred()
#   %.38.not = icmp eq i8* %.37, null
#   br i1 %.38.not, label %entry.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %.42 = load i8*, i8** %.6, align 8
#   %.45 = call i8* @PyNumber_Long(i8* %.42)
#   %.46.not = icmp eq i8* %.45, null
#   br i1 %.46.not, label %entry.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.if:                 ; preds = %entry.endif.endif.endif.endif
#   %.48 = call i64 @PyLong_AsLongLong(i8* nonnull %.45)
#   call void @Py_DecRef(i8* nonnull %.45)
#   br label %entry.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif
#   %.53 = call i8* @PyErr_Occurred()
#   %.54.not = icmp eq i8* %.53, null
#   br i1 %.54.not, label %entry.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   %.58 = load i8*, i8** %.7, align 8
#   %.61 = call i8* @PyNumber_Long(i8* %.58)
#   %.62.not = icmp eq i8* %.61, null
#   br i1 %.62.not, label %entry.endif.endif.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   %.64 = call i64 @PyLong_AsLongLong(i8* nonnull %.61)
#   call void @Py_DecRef(i8* nonnull %.61)
#   br label %entry.endif.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif.endif.endif:  ; preds = %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.endif
#   %.69 = call i8* @PyErr_Occurred()
#   %.70.not = icmp eq i8* %.69, null
#   br i1 %.70.not, label %entry.endif.endif.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif.endif
#   store i8* null, i8** %.74, align 8
#   %.78 = call i32 @_ZN8__main__8functionB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29EN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8** nonnull %.74, { i8*, i32, i8*, i8*, i32 }** nonnull undef, i64 undef, i64 undef, i64 undef) #1
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   br label %common.ret
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# attributes #0 = { mustprogress nofree norecurse nosync nounwind willreturn writeonly }
# attributes #1 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}
#
# (int64, int64, int64, float64, omitted(default=1.49012000000001e-08), omitted(default=0.0), omitted(default=None))
# ; ModuleID = 'function'
# source_filename = "<string>"
# target datalayout = "e-m:o-i64:64-i128:128-n32:64-S128"
# target triple = "arm64-apple-darwin23.1.0"
#
# @.const.function = internal constant [9 x i8] c"function\00"
# @_ZN08NumbaEnv8__main__8functionB2v5B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29 = common local_unnamed_addr global i8* null
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v5B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29" = internal constant [214 x i8] c"missing Environment: _ZN08NumbaEnv8__main__8functionB2v5B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29\00"
# @_Py_NoneStruct = external global i8
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind willreturn writeonly
# define i32 @_ZN8__main__8functionB2v5B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture readnone %excinfo, i64 %arg.a, i64 %arg.b, i64 %arg.c, double %arg.d) local_unnamed_addr #0 {
# entry:
#   store i8* null, i8** %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__8functionB2v5B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = alloca i8*, align 8
#   %.8 = alloca i8*, align 8
#   %.9 = alloca i8*, align 8
#   %.10 = alloca i8*, align 8
#   %.11 = alloca i8*, align 8
#   %.12 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([9 x i8], [9 x i8]* @.const.function, i64 0, i64 0), i64 7, i64 7, i8** nonnull %.5, i8** nonnull %.6, i8** nonnull %.7, i8** nonnull %.8, i8** nonnull %.9, i8** nonnull %.10, i8** nonnull %.11)
#   %.13 = icmp eq i32 %.12, 0
#   %.83 = alloca i8*, align 8
#   store i8* null, i8** %.83, align 8
#   br i1 %.13, label %common.ret, label %entry.endif, !prof !0
#
# common.ret:                                       ; preds = %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry, %entry.endif.endif.endif.e...endif, %entry.endif.if
#   %common.ret.op = phi i8* [ null, %entry.endif.if ], [ @_Py_NoneStruct, %entry.endif.endif.endif.e...endif ], [ null, %entry ], [ null, %entry.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif.endif ]
#   ret i8* %common.ret.op
#
# entry.endif:                                      ; preds = %entry
#   %.17 = load i8*, i8** @_ZN08NumbaEnv8__main__8functionB2v5B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29, align 8
#   %.22 = icmp eq i8* %.17, null
#   br i1 %.22, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([214 x i8], [214 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v5B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29", i64 0, i64 0))
#   br label %common.ret
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.26 = load i8*, i8** %.5, align 8
#   %.29 = call i8* @PyNumber_Long(i8* %.26)
#   %.30.not = icmp eq i8* %.29, null
#   br i1 %.30.not, label %entry.endif.endif.endif, label %entry.endif.endif.if, !prof !0
#
# entry.endif.endif.if:                             ; preds = %entry.endif.endif
#   %.32 = call i64 @PyLong_AsLongLong(i8* nonnull %.29)
#   call void @Py_DecRef(i8* nonnull %.29)
#   br label %entry.endif.endif.endif
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif.if, %entry.endif.endif
#   %.37 = call i8* @PyErr_Occurred()
#   %.38.not = icmp eq i8* %.37, null
#   br i1 %.38.not, label %entry.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %.42 = load i8*, i8** %.6, align 8
#   %.45 = call i8* @PyNumber_Long(i8* %.42)
#   %.46.not = icmp eq i8* %.45, null
#   br i1 %.46.not, label %entry.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.if:                 ; preds = %entry.endif.endif.endif.endif
#   %.48 = call i64 @PyLong_AsLongLong(i8* nonnull %.45)
#   call void @Py_DecRef(i8* nonnull %.45)
#   br label %entry.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif
#   %.53 = call i8* @PyErr_Occurred()
#   %.54.not = icmp eq i8* %.53, null
#   br i1 %.54.not, label %entry.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   %.58 = load i8*, i8** %.7, align 8
#   %.61 = call i8* @PyNumber_Long(i8* %.58)
#   %.62.not = icmp eq i8* %.61, null
#   br i1 %.62.not, label %entry.endif.endif.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   %.64 = call i64 @PyLong_AsLongLong(i8* nonnull %.61)
#   call void @Py_DecRef(i8* nonnull %.61)
#   br label %entry.endif.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif.endif.endif:  ; preds = %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.endif
#   %.69 = call i8* @PyErr_Occurred()
#   %.70.not = icmp eq i8* %.69, null
#   br i1 %.70.not, label %entry.endif.endif.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif.endif
#   %.74 = load i8*, i8** %.8, align 8
#   %.75 = call i8* @PyNumber_Float(i8* %.74)
#   %.76 = call double @PyFloat_AsDouble(i8* %.75)
#   call void @Py_DecRef(i8* %.75)
#   %.78 = call i8* @PyErr_Occurred()
#   %.79.not = icmp eq i8* %.78, null
#   br i1 %.79.not, label %entry.endif.endif.endif.e...endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif:                ; preds = %entry.endif.endif.endif.endif.endif.endif.endif.endif
#   store i8* null, i8** %.83, align 8
#   %.87 = call i32 @_ZN8__main__8functionB2v5B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29EN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8** nonnull %.83, { i8*, i32, i8*, i8*, i32 }** nonnull undef, i64 undef, i64 undef, i64 undef, double undef) #1
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   br label %common.ret
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyNumber_Float(i8*) local_unnamed_addr
#
# declare double @PyFloat_AsDouble(i8*) local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# attributes #0 = { mustprogress nofree norecurse nosync nounwind willreturn writeonly }
# attributes #1 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}
#
# (int64, int64, int64, float64, float64, omitted(default=0.0), omitted(default=None))
# ; ModuleID = 'function'
# source_filename = "<string>"
# target datalayout = "e-m:o-i64:64-i128:128-n32:64-S128"
# target triple = "arm64-apple-darwin23.1.0"
#
# @.const.function = internal constant [9 x i8] c"function\00"
# @_ZN08NumbaEnv8__main__8functionB2v6B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29 = common local_unnamed_addr global i8* null
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v6B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29" = internal constant [164 x i8] c"missing Environment: _ZN08NumbaEnv8__main__8functionB2v6B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29\00"
# @_Py_NoneStruct = external global i8
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind willreturn writeonly
# define i32 @_ZN8__main__8functionB2v6B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture readnone %excinfo, i64 %arg.a, i64 %arg.b, i64 %arg.c, double %arg.d, double %arg.e) local_unnamed_addr #0 {
# entry:
#   store i8* null, i8** %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__8functionB2v6B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = alloca i8*, align 8
#   %.8 = alloca i8*, align 8
#   %.9 = alloca i8*, align 8
#   %.10 = alloca i8*, align 8
#   %.11 = alloca i8*, align 8
#   %.12 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([9 x i8], [9 x i8]* @.const.function, i64 0, i64 0), i64 7, i64 7, i8** nonnull %.5, i8** nonnull %.6, i8** nonnull %.7, i8** nonnull %.8, i8** nonnull %.9, i8** nonnull %.10, i8** nonnull %.11)
#   %.13 = icmp eq i32 %.12, 0
#   %.92 = alloca i8*, align 8
#   store i8* null, i8** %.92, align 8
#   br i1 %.13, label %common.ret, label %entry.endif, !prof !0
#
# common.ret:                                       ; preds = %entry.endif.endif.endif.e...endif, %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry, %entry.endif.endif.endif.e...endif.endif, %entry.endif.if
#   %common.ret.op = phi i8* [ null, %entry.endif.if ], [ @_Py_NoneStruct, %entry.endif.endif.endif.e...endif.endif ], [ null, %entry ], [ null, %entry.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.e...endif ]
#   ret i8* %common.ret.op
#
# entry.endif:                                      ; preds = %entry
#   %.17 = load i8*, i8** @_ZN08NumbaEnv8__main__8functionB2v6B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29, align 8
#   %.22 = icmp eq i8* %.17, null
#   br i1 %.22, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([164 x i8], [164 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v6B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29", i64 0, i64 0))
#   br label %common.ret
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.26 = load i8*, i8** %.5, align 8
#   %.29 = call i8* @PyNumber_Long(i8* %.26)
#   %.30.not = icmp eq i8* %.29, null
#   br i1 %.30.not, label %entry.endif.endif.endif, label %entry.endif.endif.if, !prof !0
#
# entry.endif.endif.if:                             ; preds = %entry.endif.endif
#   %.32 = call i64 @PyLong_AsLongLong(i8* nonnull %.29)
#   call void @Py_DecRef(i8* nonnull %.29)
#   br label %entry.endif.endif.endif
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif.if, %entry.endif.endif
#   %.37 = call i8* @PyErr_Occurred()
#   %.38.not = icmp eq i8* %.37, null
#   br i1 %.38.not, label %entry.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %.42 = load i8*, i8** %.6, align 8
#   %.45 = call i8* @PyNumber_Long(i8* %.42)
#   %.46.not = icmp eq i8* %.45, null
#   br i1 %.46.not, label %entry.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.if:                 ; preds = %entry.endif.endif.endif.endif
#   %.48 = call i64 @PyLong_AsLongLong(i8* nonnull %.45)
#   call void @Py_DecRef(i8* nonnull %.45)
#   br label %entry.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif
#   %.53 = call i8* @PyErr_Occurred()
#   %.54.not = icmp eq i8* %.53, null
#   br i1 %.54.not, label %entry.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   %.58 = load i8*, i8** %.7, align 8
#   %.61 = call i8* @PyNumber_Long(i8* %.58)
#   %.62.not = icmp eq i8* %.61, null
#   br i1 %.62.not, label %entry.endif.endif.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   %.64 = call i64 @PyLong_AsLongLong(i8* nonnull %.61)
#   call void @Py_DecRef(i8* nonnull %.61)
#   br label %entry.endif.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif.endif.endif:  ; preds = %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.endif
#   %.69 = call i8* @PyErr_Occurred()
#   %.70.not = icmp eq i8* %.69, null
#   br i1 %.70.not, label %entry.endif.endif.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif.endif
#   %.74 = load i8*, i8** %.8, align 8
#   %.75 = call i8* @PyNumber_Float(i8* %.74)
#   %.76 = call double @PyFloat_AsDouble(i8* %.75)
#   call void @Py_DecRef(i8* %.75)
#   %.78 = call i8* @PyErr_Occurred()
#   %.79.not = icmp eq i8* %.78, null
#   br i1 %.79.not, label %entry.endif.endif.endif.e...endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif:                ; preds = %entry.endif.endif.endif.endif.endif.endif.endif.endif
#   %.83 = load i8*, i8** %.9, align 8
#   %.84 = call i8* @PyNumber_Float(i8* %.83)
#   %.85 = call double @PyFloat_AsDouble(i8* %.84)
#   call void @Py_DecRef(i8* %.84)
#   %.87 = call i8* @PyErr_Occurred()
#   %.88.not = icmp eq i8* %.87, null
#   br i1 %.88.not, label %entry.endif.endif.endif.e...endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif:          ; preds = %entry.endif.endif.endif.e...endif
#   store i8* null, i8** %.92, align 8
#   %.96 = call i32 @_ZN8__main__8functionB2v6B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29E27omitted_28default_3dNone_29(i8** nonnull %.92, { i8*, i32, i8*, i8*, i32 }** nonnull undef, i64 undef, i64 undef, i64 undef, double undef, double undef) #1
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   br label %common.ret
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyNumber_Float(i8*) local_unnamed_addr
#
# declare double @PyFloat_AsDouble(i8*) local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# attributes #0 = { mustprogress nofree norecurse nosync nounwind willreturn writeonly }
# attributes #1 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}
#
# (int64, int64, int64, float64, float64, float64, omitted(default=None))
# ; ModuleID = 'function'
# source_filename = "<string>"
# target datalayout = "e-m:o-i64:64-i128:128-n32:64-S128"
# target triple = "arm64-apple-darwin23.1.0"
#
# @.const.function = internal constant [9 x i8] c"function\00"
# @_ZN08NumbaEnv8__main__8functionB2v7B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddd27omitted_28default_3dNone_29 = common local_unnamed_addr global i8* null
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v7B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddd27omitted_28default_3dNone_29" = internal constant [134 x i8] c"missing Environment: _ZN08NumbaEnv8__main__8functionB2v7B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddd27omitted_28default_3dNone_29\00"
# @_Py_NoneStruct = external global i8
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind willreturn writeonly
# define i32 @_ZN8__main__8functionB2v7B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddd27omitted_28default_3dNone_29(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture readnone %excinfo, i64 %arg.a, i64 %arg.b, i64 %arg.c, double %arg.d, double %arg.e, double %arg.f) local_unnamed_addr #0 {
# entry:
#   store i8* null, i8** %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__8functionB2v7B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddd27omitted_28default_3dNone_29(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = alloca i8*, align 8
#   %.8 = alloca i8*, align 8
#   %.9 = alloca i8*, align 8
#   %.10 = alloca i8*, align 8
#   %.11 = alloca i8*, align 8
#   %.12 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([9 x i8], [9 x i8]* @.const.function, i64 0, i64 0), i64 7, i64 7, i8** nonnull %.5, i8** nonnull %.6, i8** nonnull %.7, i8** nonnull %.8, i8** nonnull %.9, i8** nonnull %.10, i8** nonnull %.11)
#   %.13 = icmp eq i32 %.12, 0
#   %.101 = alloca i8*, align 8
#   store i8* null, i8** %.101, align 8
#   br i1 %.13, label %common.ret, label %entry.endif, !prof !0
#
# common.ret:                                       ; preds = %entry.endif.endif.endif.e...endif.endif, %entry.endif.endif.endif.e...endif, %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry, %entry.endif.endif.endif.e...endif.endif.endif, %entry.endif.if
#   %common.ret.op = phi i8* [ null, %entry.endif.if ], [ @_Py_NoneStruct, %entry.endif.endif.endif.e...endif.endif.endif ], [ null, %entry ], [ null, %entry.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.e...endif ], [ null, %entry.endif.endif.endif.e...endif.endif ]
#   ret i8* %common.ret.op
#
# entry.endif:                                      ; preds = %entry
#   %.17 = load i8*, i8** @_ZN08NumbaEnv8__main__8functionB2v7B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddd27omitted_28default_3dNone_29, align 8
#   %.22 = icmp eq i8* %.17, null
#   br i1 %.22, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([134 x i8], [134 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v7B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddd27omitted_28default_3dNone_29", i64 0, i64 0))
#   br label %common.ret
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.26 = load i8*, i8** %.5, align 8
#   %.29 = call i8* @PyNumber_Long(i8* %.26)
#   %.30.not = icmp eq i8* %.29, null
#   br i1 %.30.not, label %entry.endif.endif.endif, label %entry.endif.endif.if, !prof !0
#
# entry.endif.endif.if:                             ; preds = %entry.endif.endif
#   %.32 = call i64 @PyLong_AsLongLong(i8* nonnull %.29)
#   call void @Py_DecRef(i8* nonnull %.29)
#   br label %entry.endif.endif.endif
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif.if, %entry.endif.endif
#   %.37 = call i8* @PyErr_Occurred()
#   %.38.not = icmp eq i8* %.37, null
#   br i1 %.38.not, label %entry.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %.42 = load i8*, i8** %.6, align 8
#   %.45 = call i8* @PyNumber_Long(i8* %.42)
#   %.46.not = icmp eq i8* %.45, null
#   br i1 %.46.not, label %entry.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.if:                 ; preds = %entry.endif.endif.endif.endif
#   %.48 = call i64 @PyLong_AsLongLong(i8* nonnull %.45)
#   call void @Py_DecRef(i8* nonnull %.45)
#   br label %entry.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif
#   %.53 = call i8* @PyErr_Occurred()
#   %.54.not = icmp eq i8* %.53, null
#   br i1 %.54.not, label %entry.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   %.58 = load i8*, i8** %.7, align 8
#   %.61 = call i8* @PyNumber_Long(i8* %.58)
#   %.62.not = icmp eq i8* %.61, null
#   br i1 %.62.not, label %entry.endif.endif.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   %.64 = call i64 @PyLong_AsLongLong(i8* nonnull %.61)
#   call void @Py_DecRef(i8* nonnull %.61)
#   br label %entry.endif.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif.endif.endif:  ; preds = %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.endif
#   %.69 = call i8* @PyErr_Occurred()
#   %.70.not = icmp eq i8* %.69, null
#   br i1 %.70.not, label %entry.endif.endif.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif.endif
#   %.74 = load i8*, i8** %.8, align 8
#   %.75 = call i8* @PyNumber_Float(i8* %.74)
#   %.76 = call double @PyFloat_AsDouble(i8* %.75)
#   call void @Py_DecRef(i8* %.75)
#   %.78 = call i8* @PyErr_Occurred()
#   %.79.not = icmp eq i8* %.78, null
#   br i1 %.79.not, label %entry.endif.endif.endif.e...endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif:                ; preds = %entry.endif.endif.endif.endif.endif.endif.endif.endif
#   %.83 = load i8*, i8** %.9, align 8
#   %.84 = call i8* @PyNumber_Float(i8* %.83)
#   %.85 = call double @PyFloat_AsDouble(i8* %.84)
#   call void @Py_DecRef(i8* %.84)
#   %.87 = call i8* @PyErr_Occurred()
#   %.88.not = icmp eq i8* %.87, null
#   br i1 %.88.not, label %entry.endif.endif.endif.e...endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif:          ; preds = %entry.endif.endif.endif.e...endif
#   %.92 = load i8*, i8** %.10, align 8
#   %.93 = call i8* @PyNumber_Float(i8* %.92)
#   %.94 = call double @PyFloat_AsDouble(i8* %.93)
#   call void @Py_DecRef(i8* %.93)
#   %.96 = call i8* @PyErr_Occurred()
#   %.97.not = icmp eq i8* %.96, null
#   br i1 %.97.not, label %entry.endif.endif.endif.e...endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif.endif:    ; preds = %entry.endif.endif.endif.e...endif.endif
#   store i8* null, i8** %.101, align 8
#   %.105 = call i32 @_ZN8__main__8functionB2v7B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddd27omitted_28default_3dNone_29(i8** nonnull %.101, { i8*, i32, i8*, i8*, i32 }** nonnull undef, i64 undef, i64 undef, i64 undef, double undef, double undef, double undef) #1
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   br label %common.ret
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyNumber_Float(i8*) local_unnamed_addr
#
# declare double @PyFloat_AsDouble(i8*) local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# attributes #0 = { mustprogress nofree norecurse nosync nounwind willreturn writeonly }
# attributes #1 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}
#
# (int64, int64, int64, omitted(default=1.49012e-08), float64, float64, int64)
# ; ModuleID = 'function'
# source_filename = "<string>"
# target datalayout = "e-m:o-i64:64-i128:128-n32:64-S128"
# target triple = "arm64-apple-darwin23.1.0"
#
# @.const.function = internal constant [9 x i8] c"function\00"
# @_ZN08NumbaEnv8__main__8functionB2v8B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29Eddx = common local_unnamed_addr global i8* null
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v8B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29Eddx" = internal constant [147 x i8] c"missing Environment: _ZN08NumbaEnv8__main__8functionB2v8B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29Eddx\00"
# @_Py_NoneStruct = external global i8
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind willreturn writeonly
# define i32 @_ZN8__main__8functionB2v8B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29Eddx(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture readnone %excinfo, i64 %arg.a, i64 %arg.b, i64 %arg.c, double %arg.e, double %arg.f, i64 %arg.g) local_unnamed_addr #0 {
# entry:
#   store i8* null, i8** %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__8functionB2v8B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29Eddx(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = alloca i8*, align 8
#   %.8 = alloca i8*, align 8
#   %.9 = alloca i8*, align 8
#   %.10 = alloca i8*, align 8
#   %.11 = alloca i8*, align 8
#   %.12 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([9 x i8], [9 x i8]* @.const.function, i64 0, i64 0), i64 7, i64 7, i8** nonnull %.5, i8** nonnull %.6, i8** nonnull %.7, i8** nonnull %.8, i8** nonnull %.9, i8** nonnull %.10, i8** nonnull %.11)
#   %.13 = icmp eq i32 %.12, 0
#   %.108 = alloca i8*, align 8
#   store i8* null, i8** %.108, align 8
#   br i1 %.13, label %common.ret, label %entry.endif, !prof !0
#
# common.ret:                                       ; preds = %entry.endif.endif.endif.e...endif.endif.endif, %entry.endif.endif.endif.e...endif, %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry, %entry.endif.endif.endif.e...endif.endif.endif.endif, %entry.endif.if
#   %common.ret.op = phi i8* [ null, %entry.endif.if ], [ @_Py_NoneStruct, %entry.endif.endif.endif.e...endif.endif.endif.endif ], [ null, %entry ], [ null, %entry.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.e...endif ], [ null, %entry.endif.endif.endif.e...endif.endif.endif ]
#   ret i8* %common.ret.op
#
# entry.endif:                                      ; preds = %entry
#   %.17 = load i8*, i8** @_ZN08NumbaEnv8__main__8functionB2v8B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29Eddx, align 8
#   %.22 = icmp eq i8* %.17, null
#   br i1 %.22, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([147 x i8], [147 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v8B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29Eddx", i64 0, i64 0))
#   br label %common.ret
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.26 = load i8*, i8** %.5, align 8
#   %.29 = call i8* @PyNumber_Long(i8* %.26)
#   %.30.not = icmp eq i8* %.29, null
#   br i1 %.30.not, label %entry.endif.endif.endif, label %entry.endif.endif.if, !prof !0
#
# entry.endif.endif.if:                             ; preds = %entry.endif.endif
#   %.32 = call i64 @PyLong_AsLongLong(i8* nonnull %.29)
#   call void @Py_DecRef(i8* nonnull %.29)
#   br label %entry.endif.endif.endif
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif.if, %entry.endif.endif
#   %.37 = call i8* @PyErr_Occurred()
#   %.38.not = icmp eq i8* %.37, null
#   br i1 %.38.not, label %entry.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %.42 = load i8*, i8** %.6, align 8
#   %.45 = call i8* @PyNumber_Long(i8* %.42)
#   %.46.not = icmp eq i8* %.45, null
#   br i1 %.46.not, label %entry.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.if:                 ; preds = %entry.endif.endif.endif.endif
#   %.48 = call i64 @PyLong_AsLongLong(i8* nonnull %.45)
#   call void @Py_DecRef(i8* nonnull %.45)
#   br label %entry.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif
#   %.53 = call i8* @PyErr_Occurred()
#   %.54.not = icmp eq i8* %.53, null
#   br i1 %.54.not, label %entry.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   %.58 = load i8*, i8** %.7, align 8
#   %.61 = call i8* @PyNumber_Long(i8* %.58)
#   %.62.not = icmp eq i8* %.61, null
#   br i1 %.62.not, label %entry.endif.endif.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   %.64 = call i64 @PyLong_AsLongLong(i8* nonnull %.61)
#   call void @Py_DecRef(i8* nonnull %.61)
#   br label %entry.endif.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif.endif.endif:  ; preds = %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.endif
#   %.69 = call i8* @PyErr_Occurred()
#   %.70.not = icmp eq i8* %.69, null
#   br i1 %.70.not, label %entry.endif.endif.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif.endif
#   %.74 = load i8*, i8** %.9, align 8
#   %.75 = call i8* @PyNumber_Float(i8* %.74)
#   %.76 = call double @PyFloat_AsDouble(i8* %.75)
#   call void @Py_DecRef(i8* %.75)
#   %.78 = call i8* @PyErr_Occurred()
#   %.79.not = icmp eq i8* %.78, null
#   br i1 %.79.not, label %entry.endif.endif.endif.e...endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif:                ; preds = %entry.endif.endif.endif.endif.endif.endif.endif.endif
#   %.83 = load i8*, i8** %.10, align 8
#   %.84 = call i8* @PyNumber_Float(i8* %.83)
#   %.85 = call double @PyFloat_AsDouble(i8* %.84)
#   call void @Py_DecRef(i8* %.84)
#   %.87 = call i8* @PyErr_Occurred()
#   %.88.not = icmp eq i8* %.87, null
#   br i1 %.88.not, label %entry.endif.endif.endif.e...endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif:          ; preds = %entry.endif.endif.endif.e...endif
#   %.92 = load i8*, i8** %.11, align 8
#   %.95 = call i8* @PyNumber_Long(i8* %.92)
#   %.96.not = icmp eq i8* %.95, null
#   br i1 %.96.not, label %entry.endif.endif.endif.e...endif.endif.endif, label %entry.endif.endif.endif.e...endif.endif.if, !prof !0
#
# entry.endif.endif.endif.e...endif.endif.if:       ; preds = %entry.endif.endif.endif.e...endif.endif
#   %.98 = call i64 @PyLong_AsLongLong(i8* nonnull %.95)
#   call void @Py_DecRef(i8* nonnull %.95)
#   br label %entry.endif.endif.endif.e...endif.endif.endif
#
# entry.endif.endif.endif.e...endif.endif.endif:    ; preds = %entry.endif.endif.endif.e...endif.endif.if, %entry.endif.endif.endif.e...endif.endif
#   %.103 = call i8* @PyErr_Occurred()
#   %.104.not = icmp eq i8* %.103, null
#   br i1 %.104.not, label %entry.endif.endif.endif.e...endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.e...endif.endif.endif
#   store i8* null, i8** %.108, align 8
#   %.112 = call i32 @_ZN8__main__8functionB2v8B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxN21omitted_28default_3d115_49012e_2d08_29Eddx(i8** nonnull %.108, { i8*, i32, i8*, i8*, i32 }** nonnull undef, i64 undef, i64 undef, i64 undef, double undef, double undef, i64 undef) #1
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   br label %common.ret
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyNumber_Float(i8*) local_unnamed_addr
#
# declare double @PyFloat_AsDouble(i8*) local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# attributes #0 = { mustprogress nofree norecurse nosync nounwind willreturn writeonly }
# attributes #1 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}
#
# (int64, int64, int64, float64, omitted(default=1.49012000000001e-08), float64, int64)
# ; ModuleID = 'function'
# source_filename = "<string>"
# target datalayout = "e-m:o-i64:64-i128:128-n32:64-S128"
# target triple = "arm64-apple-darwin23.1.0"
#
# @.const.function = internal constant [9 x i8] c"function\00"
# @_ZN08NumbaEnv8__main__8functionB2v9B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29Edx = common local_unnamed_addr global i8* null
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v9B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29Edx" = internal constant [156 x i8] c"missing Environment: _ZN08NumbaEnv8__main__8functionB2v9B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29Edx\00"
# @_Py_NoneStruct = external global i8
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind willreturn writeonly
# define i32 @_ZN8__main__8functionB2v9B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29Edx(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture readnone %excinfo, i64 %arg.a, i64 %arg.b, i64 %arg.c, double %arg.d, double %arg.f, i64 %arg.g) local_unnamed_addr #0 {
# entry:
#   store i8* null, i8** %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__8functionB2v9B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29Edx(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = alloca i8*, align 8
#   %.8 = alloca i8*, align 8
#   %.9 = alloca i8*, align 8
#   %.10 = alloca i8*, align 8
#   %.11 = alloca i8*, align 8
#   %.12 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([9 x i8], [9 x i8]* @.const.function, i64 0, i64 0), i64 7, i64 7, i8** nonnull %.5, i8** nonnull %.6, i8** nonnull %.7, i8** nonnull %.8, i8** nonnull %.9, i8** nonnull %.10, i8** nonnull %.11)
#   %.13 = icmp eq i32 %.12, 0
#   %.108 = alloca i8*, align 8
#   store i8* null, i8** %.108, align 8
#   br i1 %.13, label %common.ret, label %entry.endif, !prof !0
#
# common.ret:                                       ; preds = %entry.endif.endif.endif.e...endif.endif.endif, %entry.endif.endif.endif.e...endif, %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry, %entry.endif.endif.endif.e...endif.endif.endif.endif, %entry.endif.if
#   %common.ret.op = phi i8* [ null, %entry.endif.if ], [ @_Py_NoneStruct, %entry.endif.endif.endif.e...endif.endif.endif.endif ], [ null, %entry ], [ null, %entry.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.e...endif ], [ null, %entry.endif.endif.endif.e...endif.endif.endif ]
#   ret i8* %common.ret.op
#
# entry.endif:                                      ; preds = %entry
#   %.17 = load i8*, i8** @_ZN08NumbaEnv8__main__8functionB2v9B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29Edx, align 8
#   %.22 = icmp eq i8* %.17, null
#   br i1 %.22, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([156 x i8], [156 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB2v9B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29Edx", i64 0, i64 0))
#   br label %common.ret
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.26 = load i8*, i8** %.5, align 8
#   %.29 = call i8* @PyNumber_Long(i8* %.26)
#   %.30.not = icmp eq i8* %.29, null
#   br i1 %.30.not, label %entry.endif.endif.endif, label %entry.endif.endif.if, !prof !0
#
# entry.endif.endif.if:                             ; preds = %entry.endif.endif
#   %.32 = call i64 @PyLong_AsLongLong(i8* nonnull %.29)
#   call void @Py_DecRef(i8* nonnull %.29)
#   br label %entry.endif.endif.endif
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif.if, %entry.endif.endif
#   %.37 = call i8* @PyErr_Occurred()
#   %.38.not = icmp eq i8* %.37, null
#   br i1 %.38.not, label %entry.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %.42 = load i8*, i8** %.6, align 8
#   %.45 = call i8* @PyNumber_Long(i8* %.42)
#   %.46.not = icmp eq i8* %.45, null
#   br i1 %.46.not, label %entry.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.if:                 ; preds = %entry.endif.endif.endif.endif
#   %.48 = call i64 @PyLong_AsLongLong(i8* nonnull %.45)
#   call void @Py_DecRef(i8* nonnull %.45)
#   br label %entry.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif
#   %.53 = call i8* @PyErr_Occurred()
#   %.54.not = icmp eq i8* %.53, null
#   br i1 %.54.not, label %entry.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   %.58 = load i8*, i8** %.7, align 8
#   %.61 = call i8* @PyNumber_Long(i8* %.58)
#   %.62.not = icmp eq i8* %.61, null
#   br i1 %.62.not, label %entry.endif.endif.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   %.64 = call i64 @PyLong_AsLongLong(i8* nonnull %.61)
#   call void @Py_DecRef(i8* nonnull %.61)
#   br label %entry.endif.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif.endif.endif:  ; preds = %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.endif
#   %.69 = call i8* @PyErr_Occurred()
#   %.70.not = icmp eq i8* %.69, null
#   br i1 %.70.not, label %entry.endif.endif.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif.endif
#   %.74 = load i8*, i8** %.8, align 8
#   %.75 = call i8* @PyNumber_Float(i8* %.74)
#   %.76 = call double @PyFloat_AsDouble(i8* %.75)
#   call void @Py_DecRef(i8* %.75)
#   %.78 = call i8* @PyErr_Occurred()
#   %.79.not = icmp eq i8* %.78, null
#   br i1 %.79.not, label %entry.endif.endif.endif.e...endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif:                ; preds = %entry.endif.endif.endif.endif.endif.endif.endif.endif
#   %.83 = load i8*, i8** %.10, align 8
#   %.84 = call i8* @PyNumber_Float(i8* %.83)
#   %.85 = call double @PyFloat_AsDouble(i8* %.84)
#   call void @Py_DecRef(i8* %.84)
#   %.87 = call i8* @PyErr_Occurred()
#   %.88.not = icmp eq i8* %.87, null
#   br i1 %.88.not, label %entry.endif.endif.endif.e...endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif:          ; preds = %entry.endif.endif.endif.e...endif
#   %.92 = load i8*, i8** %.11, align 8
#   %.95 = call i8* @PyNumber_Long(i8* %.92)
#   %.96.not = icmp eq i8* %.95, null
#   br i1 %.96.not, label %entry.endif.endif.endif.e...endif.endif.endif, label %entry.endif.endif.endif.e...endif.endif.if, !prof !0
#
# entry.endif.endif.endif.e...endif.endif.if:       ; preds = %entry.endif.endif.endif.e...endif.endif
#   %.98 = call i64 @PyLong_AsLongLong(i8* nonnull %.95)
#   call void @Py_DecRef(i8* nonnull %.95)
#   br label %entry.endif.endif.endif.e...endif.endif.endif
#
# entry.endif.endif.endif.e...endif.endif.endif:    ; preds = %entry.endif.endif.endif.e...endif.endif.if, %entry.endif.endif.endif.e...endif.endif
#   %.103 = call i8* @PyErr_Occurred()
#   %.104.not = icmp eq i8* %.103, null
#   br i1 %.104.not, label %entry.endif.endif.endif.e...endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.e...endif.endif.endif
#   store i8* null, i8** %.108, align 8
#   %.112 = call i32 @_ZN8__main__8functionB2v9B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxdN21omitted_28default_3d124_49012000000001e_2d08_29Edx(i8** nonnull %.108, { i8*, i32, i8*, i8*, i32 }** nonnull undef, i64 undef, i64 undef, i64 undef, double undef, double undef, i64 undef) #1
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   br label %common.ret
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyNumber_Float(i8*) local_unnamed_addr
#
# declare double @PyFloat_AsDouble(i8*) local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# attributes #0 = { mustprogress nofree norecurse nosync nounwind willreturn writeonly }
# attributes #1 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}
#
# (int64, int64, int64, float64, float64, omitted(default=0.0), int64)
# ; ModuleID = 'function'
# source_filename = "<string>"
# target datalayout = "e-m:o-i64:64-i128:128-n32:64-S128"
# target triple = "arm64-apple-darwin23.1.0"
#
# @.const.function = internal constant [9 x i8] c"function\00"
# @_ZN08NumbaEnv8__main__8functionB3v10B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29Ex = common local_unnamed_addr global i8* null
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB3v10B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29Ex" = internal constant [137 x i8] c"missing Environment: _ZN08NumbaEnv8__main__8functionB3v10B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29Ex\00"
# @_Py_NoneStruct = external global i8
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind willreturn writeonly
# define i32 @_ZN8__main__8functionB3v10B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29Ex(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture readnone %excinfo, i64 %arg.a, i64 %arg.b, i64 %arg.c, double %arg.d, double %arg.e, i64 %arg.g) local_unnamed_addr #0 {
# entry:
#   store i8* null, i8** %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__8functionB3v10B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29Ex(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = alloca i8*, align 8
#   %.8 = alloca i8*, align 8
#   %.9 = alloca i8*, align 8
#   %.10 = alloca i8*, align 8
#   %.11 = alloca i8*, align 8
#   %.12 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([9 x i8], [9 x i8]* @.const.function, i64 0, i64 0), i64 7, i64 7, i8** nonnull %.5, i8** nonnull %.6, i8** nonnull %.7, i8** nonnull %.8, i8** nonnull %.9, i8** nonnull %.10, i8** nonnull %.11)
#   %.13 = icmp eq i32 %.12, 0
#   %.108 = alloca i8*, align 8
#   store i8* null, i8** %.108, align 8
#   br i1 %.13, label %common.ret, label %entry.endif, !prof !0
#
# common.ret:                                       ; preds = %entry.endif.endif.endif.e...endif.endif.endif, %entry.endif.endif.endif.e...endif, %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry, %entry.endif.endif.endif.e...endif.endif.endif.endif, %entry.endif.if
#   %common.ret.op = phi i8* [ null, %entry.endif.if ], [ @_Py_NoneStruct, %entry.endif.endif.endif.e...endif.endif.endif.endif ], [ null, %entry ], [ null, %entry.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.e...endif ], [ null, %entry.endif.endif.endif.e...endif.endif.endif ]
#   ret i8* %common.ret.op
#
# entry.endif:                                      ; preds = %entry
#   %.17 = load i8*, i8** @_ZN08NumbaEnv8__main__8functionB3v10B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29Ex, align 8
#   %.22 = icmp eq i8* %.17, null
#   br i1 %.22, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([137 x i8], [137 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__8functionB3v10B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29Ex", i64 0, i64 0))
#   br label %common.ret
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.26 = load i8*, i8** %.5, align 8
#   %.29 = call i8* @PyNumber_Long(i8* %.26)
#   %.30.not = icmp eq i8* %.29, null
#   br i1 %.30.not, label %entry.endif.endif.endif, label %entry.endif.endif.if, !prof !0
#
# entry.endif.endif.if:                             ; preds = %entry.endif.endif
#   %.32 = call i64 @PyLong_AsLongLong(i8* nonnull %.29)
#   call void @Py_DecRef(i8* nonnull %.29)
#   br label %entry.endif.endif.endif
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif.if, %entry.endif.endif
#   %.37 = call i8* @PyErr_Occurred()
#   %.38.not = icmp eq i8* %.37, null
#   br i1 %.38.not, label %entry.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %.42 = load i8*, i8** %.6, align 8
#   %.45 = call i8* @PyNumber_Long(i8* %.42)
#   %.46.not = icmp eq i8* %.45, null
#   br i1 %.46.not, label %entry.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.if:                 ; preds = %entry.endif.endif.endif.endif
#   %.48 = call i64 @PyLong_AsLongLong(i8* nonnull %.45)
#   call void @Py_DecRef(i8* nonnull %.45)
#   br label %entry.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif
#   %.53 = call i8* @PyErr_Occurred()
#   %.54.not = icmp eq i8* %.53, null
#   br i1 %.54.not, label %entry.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   %.58 = load i8*, i8** %.7, align 8
#   %.61 = call i8* @PyNumber_Long(i8* %.58)
#   %.62.not = icmp eq i8* %.61, null
#   br i1 %.62.not, label %entry.endif.endif.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   %.64 = call i64 @PyLong_AsLongLong(i8* nonnull %.61)
#   call void @Py_DecRef(i8* nonnull %.61)
#   br label %entry.endif.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif.endif.endif:  ; preds = %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.endif
#   %.69 = call i8* @PyErr_Occurred()
#   %.70.not = icmp eq i8* %.69, null
#   br i1 %.70.not, label %entry.endif.endif.endif.endif.endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif.endif
#   %.74 = load i8*, i8** %.8, align 8
#   %.75 = call i8* @PyNumber_Float(i8* %.74)
#   %.76 = call double @PyFloat_AsDouble(i8* %.75)
#   call void @Py_DecRef(i8* %.75)
#   %.78 = call i8* @PyErr_Occurred()
#   %.79.not = icmp eq i8* %.78, null
#   br i1 %.79.not, label %entry.endif.endif.endif.e...endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif:                ; preds = %entry.endif.endif.endif.endif.endif.endif.endif.endif
#   %.83 = load i8*, i8** %.9, align 8
#   %.84 = call i8* @PyNumber_Float(i8* %.83)
#   %.85 = call double @PyFloat_AsDouble(i8* %.84)
#   call void @Py_DecRef(i8* %.84)
#   %.87 = call i8* @PyErr_Occurred()
#   %.88.not = icmp eq i8* %.87, null
#   br i1 %.88.not, label %entry.endif.endif.endif.e...endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif:          ; preds = %entry.endif.endif.endif.e...endif
#   %.92 = load i8*, i8** %.11, align 8
#   %.95 = call i8* @PyNumber_Long(i8* %.92)
#   %.96.not = icmp eq i8* %.95, null
#   br i1 %.96.not, label %entry.endif.endif.endif.e...endif.endif.endif, label %entry.endif.endif.endif.e...endif.endif.if, !prof !0
#
# entry.endif.endif.endif.e...endif.endif.if:       ; preds = %entry.endif.endif.endif.e...endif.endif
#   %.98 = call i64 @PyLong_AsLongLong(i8* nonnull %.95)
#   call void @Py_DecRef(i8* nonnull %.95)
#   br label %entry.endif.endif.endif.e...endif.endif.endif
#
# entry.endif.endif.endif.e...endif.endif.endif:    ; preds = %entry.endif.endif.endif.e...endif.endif.if, %entry.endif.endif.endif.e...endif.endif
#   %.103 = call i8* @PyErr_Occurred()
#   %.104.not = icmp eq i8* %.103, null
#   br i1 %.104.not, label %entry.endif.endif.endif.e...endif.endif.endif.endif, label %common.ret, !prof !1
#
# entry.endif.endif.endif.e...endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.e...endif.endif.endif
#   store i8* null, i8** %.108, align 8
#   %.112 = call i32 @_ZN8__main__8functionB3v10B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dExxxddN21omitted_28default_3d05_0_29Ex(i8** nonnull %.108, { i8*, i32, i8*, i8*, i32 }** nonnull undef, i64 undef, i64 undef, i64 undef, double undef, double undef, i64 undef) #1
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   br label %common.ret
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyNumber_Float(i8*) local_unnamed_addr
#
# declare double @PyFloat_AsDouble(i8*) local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# attributes #0 = { mustprogress nofree norecurse nosync nounwind willreturn writeonly }
# attributes #1 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}

# %%
llvm_list = list(llvm.keys())
hash(llvm_list[0])
# %timeit -n 1000 llvm[llvm_list[0]]
# Out:
# 1.05 µs ± 64.7 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %load_ext Cython
